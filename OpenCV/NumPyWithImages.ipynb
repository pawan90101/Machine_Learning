# %%
import numpy as np
import matplotlib.pyplot as plt


from PIL import Image

pic = Image.open("../DataSets/DemoImages.png")
#pic to show in jupyter
#pic.show()
type(pic)
pic_arr = np.array(pic);
pic_arr.shape
# Out:
# (568, 451, 4)

# %%
plt.imshow(pic_arr)

# %%
red_arr = pic_arr.copy()

red_arr = red_arr[:,:,0]
plt.imshow(red_arr)

# %%
plt.imshow(red_arr,cmap="gray")# closer , more red
#Red channel values 0-no red: pure black, 255- pure red
