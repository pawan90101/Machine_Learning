# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

img = cv2.imread("../DataSets/DemoImages.png")
type(img) #type is numpy.ndarray if image file exists
# Out:
# numpy.ndarray

# %%
img = cv2.imread("../DataSets/DemoImagesssssssss.png")
type(img)# NoneType if image file note exists
# Out:
# NoneType

# %%
img = cv2.imread("../DataSets/DemoImages.png")
img

img.shape
# Out:
# (568, 451, 3)

# %%
plt.imshow(img)

# %%
#matplotlib plot the image RGB reg green blue
#but openCV read this as BGR blue geen red, basialy swap the values
#so we need to transform
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img_gray = cv2.imread("../DataSets/DemoImages.png", cv2.IMREAD_GRAYSCALE)
plt.imshow(cv2.cvtColor(img_gray,cv2.COLOR_BGR2RGB))

# %%
img_gray = cv2.imread("../DataSets/DemoImages.png", cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap="gray")
